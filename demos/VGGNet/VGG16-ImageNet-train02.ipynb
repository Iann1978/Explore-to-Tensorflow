# %%
# Import keras and other Utils
import pltutils as pltu
import matplotlib.pyplot as plt
import numpy as np
import math
import cv2
import tensorflow as tf
import os


from keras.datasets import mnist
from keras.datasets import cifar10
from keras.utils import np_utils
from keras.models import Sequential, Model
from keras.layers import Dense, Activation, Conv2D
from keras.layers import Reshape, MaxPooling2D, Flatten
from keras.layers import Input, InputLayer, Lambda, Dropout
from keras.layers import BatchNormalization,Softmax
from keras.optimizers import RMSprop
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator 
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline
plt.style.use('seaborn-whitegrid')

# %%
# Create Model
model = Sequential()
model.add(Conv2D(filters=64,kernel_size=(3,3),strides=(1,1),padding='same',input_shape=(224,224,3),activation='relu'))
model.add(Conv2D(filters=64,kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'))

model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2),padding='valid'))
model.add(Conv2D(128,(3,3),padding='same',activation='relu'))
model.add(Conv2D(128,(3,3),padding='same',activation='relu'))

model.add(MaxPooling2D((2,2)))
model.add(Conv2D(256,(3,3),padding='same',activation='relu'))
model.add(Conv2D(256,(3,3),padding='same',activation='relu'))
model.add(Conv2D(256,(3,3),padding='same',activation='relu'))

model.add(MaxPooling2D((2,2)))
model.add(Conv2D(512,(3,3),padding='same',activation='relu'))
model.add(Conv2D(512,(3,3),padding='same',activation='relu'))
model.add(Conv2D(512,(3,3),padding='same',activation='relu'))

model.add(MaxPooling2D((2,2)))
model.add(Conv2D(512,(3,3),padding='same',activation='relu'))
model.add(Conv2D(512,(3,3),padding='same',activation='relu'))
model.add(Conv2D(512,(3,3),padding='same',activation='relu'))

model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(4096,activation='relu'))
model.add(Dense(4096,activation='relu'))
model.add(Dense(2,activation='softmax'))
print (model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4096)              102764544
# _________________________________________________________________
# dense_5 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 8194
# =================================================================
# Total params: 134,268,738
# Trainable params: 134,268,738
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
import keras
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer = keras.optimizers.SGD(lr=0.005, decay=1e-6, momentum=0.9, nesterov=True),
              metrics=['accuracy'])

# %%
batch_size = 32
 

#实例化对象datagen
datagen=ImageDataGenerator()   
 
#读训练集图片
train_generator = datagen.flow_from_directory(
    'e:/tensorflow/data/ImageNet/train02',
    target_size=(224, 224),
    class_mode='categorical',
    batch_size=batch_size)

validation_generator = datagen.flow_from_directory(
    'e:/tensorflow/data/ImageNet/train02',
    classes=['bird','dog'],
    target_size=(224, 224),
    class_mode='categorical',
    batch_size=batch_size)
# Out:
# Found 2600 images belonging to 2 classes.
# Found 2600 images belonging to 2 classes.

# %%
import os
checkpoint_path = "checkpoints/vgg16-class-2/checkpoint-weights_only-epoch{epoch:04d}-accuracy{accuracy:.4f}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
print(checkpoint_dir)
cp_callback=ModelCheckpoint(checkpoint_path, verbose=1, save_weights_only=True,period=1)
# Out:
# checkpoints/vgg16-class-2

# %%
model.save('checkpoints/vgg16-class-2/vgg16.h5')

# %%
model.fit_generator(generator=train_generator,steps_per_epoch=2600/batch_size,epochs=80
                   ,callbacks=[cp_callback])
                   #,validation_data=validation_generator,validation_steps=32)
# Out:
# Epoch 1/80
# 82/81 [==============================] - 37s 449ms/step - loss: 0.7201 - accuracy: 0.5488
#
# Epoch 00001: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0001-accuracy0.5488.ckpt
# Epoch 2/80
# 82/81 [==============================] - 36s 444ms/step - loss: 0.6897 - accuracy: 0.5708
#
# Epoch 00002: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0002-accuracy0.5708.ckpt
# Epoch 3/80
# 82/81 [==============================] - 36s 445ms/step - loss: 0.7031 - accuracy: 0.5519
#
# Epoch 00003: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0003-accuracy0.5519.ckpt
# Epoch 4/80
# 82/81 [==============================] - 36s 443ms/step - loss: 0.6920 - accuracy: 0.5250
#
# Epoch 00004: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0004-accuracy0.5250.ckpt
# Epoch 5/80
# 82/81 [==============================] - 36s 443ms/step - loss: 0.6606 - accuracy: 0.6088
#
# Epoch 00005: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0005-accuracy0.6088.ckpt
# Epoch 6/80
# 82/81 [==============================] - 36s 443ms/step - loss: 0.7021 - accuracy: 0.5708
#
# Epoch 00006: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0006-accuracy0.5708.ckpt
# Epoch 7/80
# 82/81 [==============================] - 36s 444ms/step - loss: 0.6907 - accuracy: 0.5250
#
# Epoch 00007: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0007-accuracy0.5250.ckpt
# Epoch 8/80
# 82/81 [==============================] - 37s 446ms/step - loss: 0.6938 - accuracy: 0.4912
#
# Epoch 00008: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0008-accuracy0.4912.ckpt
# Epoch 9/80
# 82/81 [==============================] - 37s 446ms/step - loss: 0.6935 - accuracy: 0.4815
#
# Epoch 00009: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0009-accuracy0.4815.ckpt
# Epoch 10/80
# 82/81 [==============================] - 37s 446ms/step - loss: 0.6931 - accuracy: 0.4985
#
# Epoch 00010: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0010-accuracy0.4985.ckpt
# Epoch 11/80
# 82/81 [==============================] - 37s 446ms/step - loss: 0.6923 - accuracy: 0.5173
#
# Epoch 00011: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0011-accuracy0.5173.ckpt
# Epoch 12/80
# 82/81 [==============================] - 37s 445ms/step - loss: 0.6833 - accuracy: 0.5765
#
# Epoch 00012: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0012-accuracy0.5765.ckpt
# Epoch 13/80
# 82/81 [==============================] - 36s 444ms/step - loss: 0.6948 - accuracy: 0.5096
#
# Epoch 00013: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0013-accuracy0.5096.ckpt
# Epoch 14/80
# 82/81 [==============================] - 36s 444ms/step - loss: 0.6944 - accuracy: 0.5585
#
# Epoch 00014: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0014-accuracy0.5585.ckpt
# Epoch 15/80
# 82/81 [==============================] - 36s 445ms/step - loss: 0.6934 - accuracy: 0.4846
#
# Epoch 00015: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0015-accuracy0.4846.ckpt
# Epoch 16/80
# 82/81 [==============================] - 36s 443ms/step - loss: 0.6933 - accuracy: 0.5173
#
# Epoch 00016: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0016-accuracy0.5173.ckpt
# Epoch 17/80
# 82/81 [==============================] - 36s 444ms/step - loss: 0.6939 - accuracy: 0.4977
#
# Epoch 00017: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0017-accuracy0.4977.ckpt
# Epoch 18/80
# 82/81 [==============================] - 36s 445ms/step - loss: 0.6936 - accuracy: 0.5062
#
# Epoch 00018: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0018-accuracy0.5062.ckpt
# Epoch 19/80
# 82/81 [==============================] - 37s 446ms/step - loss: 0.6916 - accuracy: 0.5112
#
# Epoch 00019: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0019-accuracy0.5112.ckpt
# Epoch 20/80
# 82/81 [==============================] - 37s 447ms/step - loss: 0.6629 - accuracy: 0.6396
#
# Epoch 00020: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0020-accuracy0.6396.ckpt
# Epoch 21/80
# 82/81 [==============================] - 37s 447ms/step - loss: 0.5762 - accuracy: 0.7096
#
# Epoch 00021: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0021-accuracy0.7096.ckpt
# Epoch 22/80
# 82/81 [==============================] - 37s 446ms/step - loss: 0.5482 - accuracy: 0.7250
#
# Epoch 00022: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0022-accuracy0.7250.ckpt
# Epoch 23/80
# 82/81 [==============================] - 37s 446ms/step - loss: 0.4665 - accuracy: 0.7992
#
# Epoch 00023: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0023-accuracy0.7992.ckpt
# Epoch 24/80
# 82/81 [==============================] - 37s 446ms/step - loss: 0.4235 - accuracy: 0.8092
#
# Epoch 00024: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0024-accuracy0.8092.ckpt
# Epoch 25/80
# 82/81 [==============================] - 37s 447ms/step - loss: 0.4083 - accuracy: 0.8212
#
# Epoch 00025: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0025-accuracy0.8212.ckpt
# Epoch 26/80
# 82/81 [==============================] - 37s 447ms/step - loss: 0.3542 - accuracy: 0.8500
#
# Epoch 00026: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0026-accuracy0.8500.ckpt
# Epoch 27/80
# 82/81 [==============================] - 37s 448ms/step - loss: 0.4188 - accuracy: 0.8123
#
# Epoch 00027: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0027-accuracy0.8123.ckpt
# Epoch 28/80
# 82/81 [==============================] - 37s 449ms/step - loss: 0.3514 - accuracy: 0.8554
#
# Epoch 00028: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0028-accuracy0.8554.ckpt
# Epoch 29/80
# 82/81 [==============================] - 37s 447ms/step - loss: 0.3525 - accuracy: 0.8500
#
# Epoch 00029: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0029-accuracy0.8500.ckpt
# Epoch 30/80
# 82/81 [==============================] - 37s 446ms/step - loss: 0.3544 - accuracy: 0.8531
#
# Epoch 00030: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0030-accuracy0.8531.ckpt
# Epoch 31/80
# 82/81 [==============================] - 37s 448ms/step - loss: 0.2822 - accuracy: 0.8765
#
# Epoch 00031: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0031-accuracy0.8765.ckpt
# Epoch 32/80
# 82/81 [==============================] - 37s 447ms/step - loss: 0.3983 - accuracy: 0.8265
#
# Epoch 00032: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0032-accuracy0.8265.ckpt
# Epoch 33/80
# 82/81 [==============================] - 37s 447ms/step - loss: 0.3003 - accuracy: 0.8685
#
# Epoch 00033: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0033-accuracy0.8685.ckpt
# Epoch 34/80
# 82/81 [==============================] - 37s 447ms/step - loss: 0.2940 - accuracy: 0.8727
#
# Epoch 00034: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0034-accuracy0.8727.ckpt
# Epoch 35/80
# 82/81 [==============================] - 37s 448ms/step - loss: 0.2308 - accuracy: 0.9046
#
# Epoch 00035: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0035-accuracy0.9046.ckpt
# Epoch 36/80
# 82/81 [==============================] - 37s 447ms/step - loss: 0.2207 - accuracy: 0.9015
#
# Epoch 00036: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0036-accuracy0.9015.ckpt
# Epoch 37/80
# 82/81 [==============================] - 37s 447ms/step - loss: 0.2016 - accuracy: 0.9238
#
# Epoch 00037: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0037-accuracy0.9238.ckpt
# Epoch 38/80
# 82/81 [==============================] - 37s 447ms/step - loss: 0.2047 - accuracy: 0.9154
#
# Epoch 00038: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0038-accuracy0.9154.ckpt
# Epoch 39/80
# 82/81 [==============================] - 37s 448ms/step - loss: 0.1652 - accuracy: 0.9342
#
# Epoch 00039: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0039-accuracy0.9342.ckpt
# Epoch 40/80
# 82/81 [==============================] - 37s 447ms/step - loss: 0.1567 - accuracy: 0.9362
#
# Epoch 00040: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0040-accuracy0.9362.ckpt
# Epoch 41/80
# 82/81 [==============================] - 37s 448ms/step - loss: 0.1402 - accuracy: 0.9435
#
# Epoch 00041: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0041-accuracy0.9435.ckpt
# Epoch 42/80
# 82/81 [==============================] - 37s 449ms/step - loss: 0.1143 - accuracy: 0.9542
#
# Epoch 00042: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0042-accuracy0.9542.ckpt
# Epoch 43/80
# 82/81 [==============================] - 37s 449ms/step - loss: 0.1035 - accuracy: 0.9608
#
# Epoch 00043: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0043-accuracy0.9608.ckpt
# Epoch 44/80
# 82/81 [==============================] - 37s 449ms/step - loss: 0.0695 - accuracy: 0.9758
#
# Epoch 00044: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0044-accuracy0.9758.ckpt
# Epoch 45/80
# 82/81 [==============================] - 37s 449ms/step - loss: 0.0667 - accuracy: 0.9731
#
# Epoch 00045: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0045-accuracy0.9731.ckpt
# Epoch 46/80
# 82/81 [==============================] - 37s 447ms/step - loss: 0.0913 - accuracy: 0.9669
#
# Epoch 00046: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0046-accuracy0.9669.ckpt
# Epoch 47/80
# 82/81 [==============================] - 37s 447ms/step - loss: 0.0533 - accuracy: 0.9808
#
# Epoch 00047: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0047-accuracy0.9808.ckpt
# Epoch 48/80
# 82/81 [==============================] - 37s 447ms/step - loss: 0.0688 - accuracy: 0.9719
#
# Epoch 00048: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0048-accuracy0.9719.ckpt
# Epoch 49/80
# 82/81 [==============================] - 37s 448ms/step - loss: 0.0465 - accuracy: 0.9831
#
# Epoch 00049: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0049-accuracy0.9831.ckpt
# Epoch 50/80
# 82/81 [==============================] - 37s 448ms/step - loss: 0.0244 - accuracy: 0.9938
#
# Epoch 00050: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0050-accuracy0.9938.ckpt
# Epoch 51/80
# 82/81 [==============================] - 37s 448ms/step - loss: 0.0600 - accuracy: 0.9804
#
# Epoch 00051: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0051-accuracy0.9804.ckpt
# Epoch 52/80
# 82/81 [==============================] - 37s 448ms/step - loss: 0.0389 - accuracy: 0.9831
#
# Epoch 00052: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0052-accuracy0.9831.ckpt
# Epoch 53/80
# 82/81 [==============================] - 37s 447ms/step - loss: 0.0056 - accuracy: 0.9985
#
# Epoch 00053: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0053-accuracy0.9985.ckpt
# Epoch 54/80
# 82/81 [==============================] - 37s 447ms/step - loss: 0.0057 - accuracy: 0.9985
#
# Epoch 00054: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0054-accuracy0.9985.ckpt
# Epoch 55/80
# 82/81 [==============================] - 37s 448ms/step - loss: 0.0340 - accuracy: 0.9873
#
# Epoch 00055: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0055-accuracy0.9873.ckpt
# Epoch 56/80
# 82/81 [==============================] - 37s 447ms/step - loss: 0.0237 - accuracy: 0.9919
#
# Epoch 00056: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0056-accuracy0.9919.ckpt
# Epoch 57/80
# 82/81 [==============================] - 37s 447ms/step - loss: 0.1103 - accuracy: 0.9577
#
# Epoch 00057: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0057-accuracy0.9577.ckpt
# Epoch 58/80
# 82/81 [==============================] - 37s 447ms/step - loss: 0.0948 - accuracy: 0.9669
#
# Epoch 00058: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0058-accuracy0.9669.ckpt
# Epoch 59/80
# 82/81 [==============================] - 37s 447ms/step - loss: 0.0428 - accuracy: 0.9865
#
# Epoch 00059: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0059-accuracy0.9865.ckpt
# Epoch 60/80
# 82/81 [==============================] - 37s 447ms/step - loss: 0.0290 - accuracy: 0.9908
#
# Epoch 00060: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0060-accuracy0.9908.ckpt
# Epoch 61/80
# 82/81 [==============================] - 37s 447ms/step - loss: 0.0272 - accuracy: 0.9912
#
# Epoch 00061: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0061-accuracy0.9912.ckpt
# Epoch 62/80
# 82/81 [==============================] - 37s 448ms/step - loss: 0.0074 - accuracy: 0.9985
#
# Epoch 00062: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0062-accuracy0.9985.ckpt
# Epoch 63/80
# 82/81 [==============================] - 37s 447ms/step - loss: 0.0016 - accuracy: 1.0000
#
# Epoch 00063: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0063-accuracy1.0000.ckpt
# Epoch 64/80
# 82/81 [==============================] - 37s 448ms/step - loss: 2.3391e-04 - accuracy: 1.0000
#
# Epoch 00064: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0064-accuracy1.0000.ckpt
# Epoch 65/80
# 82/81 [==============================] - 37s 448ms/step - loss: 7.8895e-05 - accuracy: 1.0000
#
# Epoch 00065: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0065-accuracy1.0000.ckpt
# Epoch 66/80
# 82/81 [==============================] - 37s 448ms/step - loss: 5.1655e-05 - accuracy: 1.0000
#
# Epoch 00066: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0066-accuracy1.0000.ckpt
# Epoch 67/80
# 82/81 [==============================] - 37s 449ms/step - loss: 3.8201e-05 - accuracy: 1.0000
#
# Epoch 00067: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0067-accuracy1.0000.ckpt
# Epoch 68/80
# 82/81 [==============================] - 37s 448ms/step - loss: 3.1886e-05 - accuracy: 1.0000
#
# Epoch 00068: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0068-accuracy1.0000.ckpt
# Epoch 69/80
# 82/81 [==============================] - 37s 449ms/step - loss: 2.7245e-05 - accuracy: 1.0000
#
# Epoch 00069: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0069-accuracy1.0000.ckpt
# Epoch 70/80
# 82/81 [==============================] - 37s 449ms/step - loss: 2.3889e-05 - accuracy: 1.0000
#
# Epoch 00070: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0070-accuracy1.0000.ckpt
# Epoch 71/80
# 82/81 [==============================] - 37s 448ms/step - loss: 2.1318e-05 - accuracy: 1.0000
#
# Epoch 00071: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0071-accuracy1.0000.ckpt
# Epoch 72/80
# 82/81 [==============================] - 37s 448ms/step - loss: 1.9329e-05 - accuracy: 1.0000
#
# Epoch 00072: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0072-accuracy1.0000.ckpt
# Epoch 73/80
# 82/81 [==============================] - 37s 448ms/step - loss: 1.7598e-05 - accuracy: 1.0000
#
# Epoch 00073: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0073-accuracy1.0000.ckpt
# Epoch 74/80
# 82/81 [==============================] - 37s 448ms/step - loss: 1.6206e-05 - accuracy: 1.0000
#
# Epoch 00074: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0074-accuracy1.0000.ckpt
# Epoch 75/80
# 82/81 [==============================] - 37s 448ms/step - loss: 1.4826e-05 - accuracy: 1.0000
#
# Epoch 00075: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0075-accuracy1.0000.ckpt
# Epoch 76/80
# 82/81 [==============================] - 37s 448ms/step - loss: 1.3851e-05 - accuracy: 1.0000
#
# Epoch 00076: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0076-accuracy1.0000.ckpt
# Epoch 77/80
# 82/81 [==============================] - 37s 448ms/step - loss: 1.2892e-05 - accuracy: 1.0000
#
# Epoch 00077: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0077-accuracy1.0000.ckpt
# Epoch 78/80
# 82/81 [==============================] - 37s 448ms/step - loss: 1.2079e-05 - accuracy: 1.0000
#
# Epoch 00078: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0078-accuracy1.0000.ckpt
# Epoch 79/80
# 82/81 [==============================] - 37s 448ms/step - loss: 1.1375e-05 - accuracy: 1.0000
#
# Epoch 00079: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0079-accuracy1.0000.ckpt
# Epoch 80/80
# 82/81 [==============================] - 37s 448ms/step - loss: 1.0727e-05 - accuracy: 1.0000
#
# Epoch 00080: saving model to checkpoints/vgg16-class-2/checkpoint-weights_only-epoch0080-accuracy1.0000.ckpt

# %%
model.load_weights('./training_2/cp-0004.ckpt')

# %%
model.evaluate_generator(generator=validation_generator)
# Out:
# [0.6779419779777527, 0.5003846287727356]
