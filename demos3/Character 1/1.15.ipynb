# %%
import pandas as pd

# %%
mtbe_table = pd.read_excel('MTBE.XLS')
mtbe_table
# Out:
#        pH  SpConduct  DissOxy  RoadsPct  IndPct  UrbanPct  DevPct WellClass  \
# 0    7.87      290.0     0.58      1.34    0.00     17.77   17.77   Private
# 1    8.63      225.9     0.84      0.72    0.00     10.43   10.43   Private
# 2    7.11      157.4     8.37      1.92    0.00     29.62   50.01   Private
# 3    7.98      723.6     0.41      2.76    0.00     41.65   41.65   Private
# 4    7.88      148.7     1.44      3.51    0.00     51.21   51.21   Private
# ..    ...        ...      ...       ...     ...       ...     ...       ...
# 218  7.50      264.8     8.45      2.90    4.00     47.50   52.74    Public
# 219  7.22      369.5     4.04      1.39    0.00     11.44   55.10    Public
# 220  7.84      335.6     0.41      1.55    0.00     30.06   45.99    Public
# 221  7.75      863.7     0.50      3.17   14.92     41.62   47.58    Public
# 222  6.33      431.8     3.88      1.71    2.10     28.58   54.72    Public
#
# ...

# %%
mtbe_sample5 = mtbe_table.sample(5)
mtbe_sample5
# Out:
#        pH  SpConduct  DissOxy  RoadsPct  IndPct  UrbanPct  DevPct WellClass  \
# 30   7.07      418.4     2.95      3.00    0.00     36.38   36.38   Private
# 11   7.02      494.8     1.54      2.76    0.00     77.45   89.34   Private
# 192  8.21      238.6     0.43      1.34    0.00     21.47   27.16    Public
# 121  7.28      294.0     3.33      2.59    1.67     45.22   45.64    Public
# 152  7.00      392.3     0.42      3.71    3.09     41.40   50.07    Public
#
#     Aquifier     Depth     SafeYld  Distance  MTBE-Detect  MTBE-Level  \
# 30   Bedrock   43.2816         NaN   1748.02  Below Limit        0.20
# 11   Bedrock       NaN         NaN    564.99  Below Limit        0.20
# 192  Bedrock   60.3504   18.925057    723.89  Below Limit        0.20
# 121  Bedrock   60.9600  227.100681    891.93       Detect        0.36
# 152  Bedrock  153.9240   94.625284    330.46  Below Limit        0.20
#
#      HouseDen  PopDen
# 30      99.49   33.16
# 11     206.49   55.48
# ...

# %%
https://blog.csdn.net/qq_38923076/article/details/82925238
